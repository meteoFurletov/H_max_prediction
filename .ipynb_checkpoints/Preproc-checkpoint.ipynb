# %%
import numpy as np

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Useful functions

# %%
df_sheet_map = pd.read_excel('Расчёт регрессии_220322.xlsx', sheet_name=None)
df_sheet_map

# %%
def get_nth_key(dictionary, n=0):
    if n < 0:
        n += len(dictionary)
    for i, items in enumerate(dictionary.items()):
        if i == n:
            return items
    raise IndexError("dictionary index out of range")

# %%
get_nth_key(df_sheet_map,55)
# Out:
# ('2107141320',
#                   Явление  Высота  0-750  1000-1750  2000-2750  3000-3750  \
#  0   С - А                   6000   -100       -100       -100         13
#  1   Конвективная обл.       6250     15         16         30         33
#  2   Ливень умеренный        7500     40         40         40         39
#  3   Гроза(вер-ть 70-90%)    9500     16         19         24         37
#  4   Гроза(вер-ть  > 90%)   12000     53         53         54         54
#  5   Гроза(вер-ть  > 90%)   12500     48         49         50         49
#  6   Гроза(вер-ть  > 90%)   12500     51         52         52         51
#  7   Град умеренный         13250     59         59         59         58
#  8   Град умеренный         13750     56         56         56         55
#  9   Град сильный           13750     56         57         60         59
#  10  Град умеренный         13750     56         57         59         60
# ...
